# %%
from handcrafted_datasets import Dataset
dataset = Dataset('captured', 'C:\\Users\\andre\\go-ai\\data', 0.8, 0.2, 1024)
def get_train_loader():
    dataset.shuffle('train')
    return dataset.loader('train', max_ram_files=100)
X, y = next(iter(get_train_loader()))
# Out:
# done loading data
# split sizes:
# train 552
# test 138

# %%
from visual_utils import *
k = 55
import numpy as np
#ft = np.zeros((19, 19))
#ft[y[k]//19][y[k]%19] = 1
draw_go_board(np.sum(X[k][0:3].numpy(), axis=0), np.sum(X[k][3:6].numpy(), axis=0), y[k].numpy())
# Out:
# <AxesSubplot:>

# %%
from io_utils import *
ants = read_pkl('data/filtered_annotations.pkl')

# %%
ants[46453]['comments']
# Out:
# "I guess B or even C would have been better than A. they're still close enough to the marked group and radiate towards C7. what do you think?\n\nal> I think c12 would give better shape, and prevent a cut a c14. If black plays A,B, or C, white could undercut at around c12 or c10 and cause all sorts of trouble."
